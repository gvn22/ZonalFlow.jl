# %%
# CE2 v QL tests without non-linear terms

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pylab as pl
import matplotlib as mpl

# %%
plt.rc('font', family='serif') ## setting for figures which I usually use in my publications
mpl.rcParams.update({'font.size': 12})
mpl.rcParams.update({'legend.labelspacing':0.25, 'legend.fontsize': 12})
mpl.rcParams.update({'errorbar.capsize': 4})

# %%
dn = "linear/"

# %%
# Exciting mode m = 4 for different resolutions
MODE = 3

# %%
# resolution = 6x6
M,N = 6,6

ql = np.load(dn+"ql_6x6_m3.npz",allow_pickle=True) 
ce2 = np.load(dn+"ce2_6x6_m3.npz",allow_pickle=True) 
ce2_qlic = np.load(dn+"ce2_6x6_qlic_m3.npz",allow_pickle=True)

# %%
fig,ax = plt.subplots(1,3,figsize=(12,4))

ax[0].set_title('QL')
ax[0].imshow(ql['F'])

ax[1].set_title('CE2')
ax[1].imshow(ce2['F'])

ax[2].set_title('CE2 w/ QL IC')
ax[2].imshow(ce2_qlic['F'])

for a in ax:
    a.set_xlabel('m')
    a.set_ylabel('n')

    a.set_xticks(np.arange(0,2*M-1))
    a.set_yticks(np.arange(0,2*N-1))

    a.set_xticklabels(np.arange(-M+1,M))
    a.set_yticklabels(np.arange(-N+1,N))

plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,3))

ax.plot(ql['t'],ql['Et'])
ax.plot(ce2['t'],ce2['Et'])
ax.plot(ce2_qlic['t'],ce2_qlic['Et'])

ql_mean = np.mean(ql['Et'][100:])
ax.axhline(ql_mean,ls='dashed',alpha=0.5)

ax.set_yticks([0.0,0.5,1.0,1.5,2.0,2.5])
ax.set_yticklabels([0.0,0.5,r'$\varepsilon/\mu$',1.5,2.0,2.5])

ax.set_xlabel(r'$t$',fontsize=12)
ax.set_ylabel(r'$E$',fontsize=12)

plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(15,4))

colors = pl.cm.gist_ncar(np.linspace(0,1,M))

ax[0].set_title(f'QL')
for i,x in enumerate(ql['Emtav']):    
    ax[0].plot(ql['t'],x,label=i,c=colors[i])

ax[1].set_title(f'CE2')
for i,x in enumerate(ce2['Emt']):
    ax[1].plot(ce2['t'],x,label=i,c=colors[i])

ax[2].set_title(f'CE2 w/ QL IC')
for i,x in enumerate(ce2_qlic['Emt']):
    ax[2].plot(ce2_qlic['t'],x,label=i,c=colors[i])

for a in ax:
    a.set_xlabel(r'$t$',fontsize=14)
#     a.set_yscale('log')
    a.set_ylim(0.0,2.0)

ax[0].set_ylabel(r'$E(m)$',fontsize=14)
ax[2].legend(loc=4,ncol=1)

plt.show()

# %%
# resolution = 6x6
M,N = 6,6

ql = np.load(dn+"ql_6x6.npz",allow_pickle=True) 
ce2 = np.load(dn+"ce2_6x6.npz",allow_pickle=True) 
ce2_qlic = np.load(dn+"ce2_6x6_qlic.npz",allow_pickle=True)

# %%
fig,ax = plt.subplots(1,3,figsize=(12,4))

ax[0].set_title('QL')
ax[0].imshow(ql['F'])

ax[1].set_title('CE2')
ax[1].imshow(ce2['F'])

ax[2].set_title('CE2 w/ QL IC')
ax[2].imshow(ce2_qlic['F'])

for a in ax:
    a.set_xlabel('m')
    a.set_ylabel('n')

    a.set_xticks(np.arange(0,2*M-1))
    a.set_yticks(np.arange(0,2*N-1))

    a.set_xticklabels(np.arange(-M+1,M))
    a.set_yticklabels(np.arange(-N+1,N))

plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,3))

ax.plot(ql['t'],ql['Et'])
ax.plot(ce2['t'],ce2['Et'])
ax.plot(ce2_qlic['t'],ce2_qlic['Et'])

ql_mean = np.mean(ql['Et'][100:])
ax.axhline(ql_mean,ls='dashed',alpha=0.5)

ax.set_yticks([0.0,0.5,1.0,1.5,2.0,2.5])
ax.set_yticklabels([0.0,0.5,r'$\varepsilon/\mu$',1.5,2.0,2.5])

ax.set_xlabel(r'$t$',fontsize=12)
ax.set_ylabel(r'$E$',fontsize=12)

plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(15,4))

colors = pl.cm.gist_ncar(np.linspace(0,1,M))

ax[0].set_title(f'QL')
for i,x in enumerate(ql['Emt']):    
    ax[0].plot(ql['t'],x,label=i,c=colors[i])

ax[1].set_title(f'CE2')
for i,x in enumerate(ce2['Emt']):
    ax[1].plot(ce2['t'],x,label=i,c=colors[i])

ax[2].set_title(f'CE2 w/ QL IC')
for i,x in enumerate(ce2_qlic['Emt']):
    ax[2].plot(ce2_qlic['t'],x,label=i,c=colors[i])

for a in ax:
    a.set_xlabel(r'$t$',fontsize=14)
#     a.set_yscale('log')
    a.set_ylim(1e-6,1.0)

ax[0].set_ylabel(r'$E(m)$',fontsize=14)
ax[2].legend(loc=1,ncol=1)

plt.show()

# %%
# resolution = 6x6
M,N = 6,6

ql = np.load(dn+"ql_6x6_dt0005.npz",allow_pickle=True) 
ce2 = np.load(dn+"ce2_6x6_dt0005.npz",allow_pickle=True) 
ce2_qlic = np.load(dn+"ce2_6x6_qlic_dt0005.npz",allow_pickle=True)

# %%
fig,ax = plt.subplots(figsize=(15,3))

ax.plot(ql['t'],ql['Et'])
ax.plot(ce2['t'],ce2['Et'])
ax.plot(ce2_qlic['t'],ce2_qlic['Et'])

ql_mean = np.mean(ql['Et'][100:])
ax.axhline(ql_mean,ls='dashed',alpha=0.5)

ax.set_yticks([0.0,0.5,1.0,1.5,2.0,2.5])
ax.set_yticklabels([0.0,0.5,r'$\varepsilon/\mu$',1.5,2.0,2.5])

plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(15,4))

colors = pl.cm.gist_ncar(np.linspace(0,1,M))

ax[0].set_title(f'QL')
for i,x in enumerate(ql['Emt']):    
    ax[0].plot(ql['t'],x,label=i,c=colors[i])

ax[1].set_title(f'CE2')
for i,x in enumerate(ce2['Emt']):
    ax[1].plot(ce2['t'],x,label=i,c=colors[i])

ax[2].set_title(f'CE2 w/ QL IC')
for i,x in enumerate(ce2_qlic['Emt']):
    ax[2].plot(ce2_qlic['t'],x,label=i,c=colors[i])

for a in ax:
    a.set_xlabel(r'$t$',fontsize=14)
#     a.set_yscale('log')
    a.set_ylim(0.0,1.0)

ax[0].set_ylabel(r'$E(m)$',fontsize=14)
ax[2].legend(loc=1,ncol=1)

plt.show()

# %%
# resolution = 8x8
M,N = 8,8

ql = np.load(dn+"ql_8x8.npz",allow_pickle=True) 
ce2 = np.load(dn+"ce2_8x8.npz",allow_pickle=True) 
ce2_qlic = np.load(dn+"ce2_8x8_qlic.npz",allow_pickle=True)

# %%
fig,ax = plt.subplots(1,3,figsize=(12,4))

ax[0].set_title('QL')
ax[0].imshow(ql['F'])

ax[1].set_title('CE2')
ax[1].imshow(ce2['F'])

ax[2].set_title('CE2 w/ QL IC')
ax[2].imshow(ce2_qlic['F'])

for a in ax:
    a.set_xlabel('m')
    a.set_ylabel('n')

    a.set_xticks(np.arange(0,2*M-1))
    a.set_yticks(np.arange(0,2*N-1))

    a.set_xticklabels(np.arange(-M+1,M))
    a.set_yticklabels(np.arange(-N+1,N))

plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,3))

ax.plot(ql['t'],ql['Et'])
ax.plot(ce2['t'],ce2['Et'])
ax.plot(ce2_qlic['t'],ce2_qlic['Et'])

ql_mean = np.mean(ql['Et'][100:])
ax.axhline(ql_mean,ls='dashed',alpha=0.5)

ax.set_yticks([0.0,0.5,1.0,1.5,2.0,2.5])
ax.set_yticklabels([0.0,0.5,r'$\varepsilon/\mu$',1.5,2.0,2.5])

ax.set_xlabel(r'$t$',fontsize=12)
ax.set_ylabel(r'$E$',fontsize=12)

plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(15,4))

colors = pl.cm.gist_ncar(np.linspace(0,1,M))

ax[0].set_title(f'QL')
for i,x in enumerate(ql['Emt']):    
    ax[0].plot(ql['t'],x,label=i,c=colors[i])

ax[1].set_title(f'CE2')
for i,x in enumerate(ce2['Emt']):
    ax[1].plot(ce2['t'],x,label=i,c=colors[i])

ax[2].set_title(f'CE2 w/ QL IC')
for i,x in enumerate(ce2_qlic['Emt']):
    ax[2].plot(ce2_qlic['t'],x,label=i,c=colors[i])

for a in ax:
    a.set_xlabel(r'$t$',fontsize=14)
#     a.set_yscale('log')
    a.set_ylim(0.0,1.0)

ax[0].set_ylabel(r'$E(m)$',fontsize=14)
ax[2].legend(loc=1,ncol=1)

plt.show()

# %%
# resolution = 10x10
M,N = 10,10

ql = np.load(dn+"ql_10x10.npz",allow_pickle=True) 
ce2 = np.load(dn+"ce2_10x10.npz",allow_pickle=True) 
ce2_qlic = np.load(dn+"ce2_10x10_qlic.npz",allow_pickle=True)

# %%
fig,ax = plt.subplots(1,3,figsize=(12,4))

ax[0].set_title('QL')
ax[0].imshow(ql['F'])

ax[1].set_title('CE2')
ax[1].imshow(ce2['F'])

ax[2].set_title('CE2 w/ QL IC')
ax[2].imshow(ce2_qlic['F'])

for a in ax:
    a.set_xlabel('m')
    a.set_ylabel('n')

    a.set_xticks(np.arange(0,2*M-1))
    a.set_yticks(np.arange(0,2*N-1))

    a.set_xticklabels(np.arange(-M+1,M))
    a.set_yticklabels(np.arange(-N+1,N))

plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,3))

ax.plot(ql['t'],ql['Et'])
ax.plot(ce2['t'],ce2['Et'])
ax.plot(ce2_qlic['t'],ce2_qlic['Et'])

ql_mean = np.mean(ql['Et'][100:])
ax.axhline(ql_mean,ls='dashed',alpha=0.5)

ax.set_yticks([0.0,0.5,1.0,1.5,2.0,2.5])
ax.set_yticklabels([0.0,0.5,r'$\varepsilon/\mu$',1.5,2.0,2.5])

ax.set_xlabel(r'$t$',fontsize=12)
ax.set_ylabel(r'$E$',fontsize=12)

plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(15,4))

colors = pl.cm.gist_ncar(np.linspace(0,1,M))

ax[0].set_title(f'QL')
for i,x in enumerate(ql['Emt']):    
    ax[0].plot(ql['t'],x,label=i,c=colors[i])

ax[1].set_title(f'CE2')
for i,x in enumerate(ce2['Emt']):
    ax[1].plot(ce2['t'],x,label=i,c=colors[i])

ax[2].set_title(f'CE2 w/ QL IC')
for i,x in enumerate(ce2_qlic['Emt']):
    ax[2].plot(ce2_qlic['t'],x,label=i,c=colors[i])

for a in ax:
    a.set_xlabel(r'$t$',fontsize=14)
#     a.set_yscale('log')
    a.set_ylim(0.0,1.0)

ax[0].set_ylabel(r'$E(m)$',fontsize=14)
ax[2].legend(loc=1,ncol=1)

plt.show()

# %%
# resolution = 12x12
M,N = 12,12

ql = np.load(dn+"ql_12x12.npz",allow_pickle=True) 
ce2 = np.load(dn+"ce2_12x12.npz",allow_pickle=True) 
ce2_qlic = np.load(dn+"ce2_12x12_qlic.npz",allow_pickle=True)

# %%
fig,ax = plt.subplots(1,3,figsize=(12,4))

ax[0].set_title('QL')
ax[0].imshow(ql['F'])

ax[1].set_title('CE2')
ax[1].imshow(ce2['F'])

ax[2].set_title('CE2 w/ QL IC')
ax[2].imshow(ce2_qlic['F'])

for a in ax:
    a.set_xlabel('m')
    a.set_ylabel('n')

    a.set_yticks([0,N-1-MODE,N-1,N-1+MODE,2*N-2])
    a.set_yticklabels([r'$-N$',r'$k_f$',r'$0$',r'$k_f$',r'$N$'])

    a.set_xticks([0,M-1-MODE,M-1,M-1+MODE,2*M-2])
    a.set_xticklabels([r'$-M$',r'$k_f$',r'$0$',r'$k_f$',r'$M$'])

plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,3))

ax.plot(ql['t'],ql['Et'])
ax.plot(ce2['t'],ce2['Et'])
ax.plot(ce2_qlic['t'],ce2_qlic['Et'])

ql_mean = np.mean(ql['Et'][100:])
ax.axhline(ql_mean,ls='dashed',alpha=0.5)

ax.set_yticks([0.0,0.5,1.0,1.5,2.0,2.5])
ax.set_yticklabels([0.0,0.5,r'$\varepsilon/\mu$',1.5,2.0,2.5])

ax.set_xlabel(r'$t$',fontsize=12)
ax.set_ylabel(r'$E$',fontsize=12)

plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(15,4))

colors = pl.cm.gist_ncar(np.linspace(0,1,M))

ax[0].set_title(f'QL')
for i,x in enumerate(ql['Emt']):    
    ax[0].plot(ql['t'],x,label=i,c=colors[i])

ax[1].set_title(f'CE2')
for i,x in enumerate(ce2['Emt']):
    ax[1].plot(ce2['t'],x,label=i,c=colors[i])

ax[2].set_title(f'CE2 w/ QL IC')
for i,x in enumerate(ce2_qlic['Emt']):
    ax[2].plot(ce2_qlic['t'],x,label=i,c=colors[i])

for a in ax:
    a.set_xlabel(r'$t$',fontsize=14)
#     a.set_yscale('log')
    a.set_ylim(0.0,1.0)

ax[0].set_ylabel(r'$E(m)$',fontsize=14)
ax[2].legend(loc=1,ncol=1)

plt.show()
